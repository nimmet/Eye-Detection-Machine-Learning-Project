# %%
import cv2
import numpy as np
import os
from glob import glob
import shutil
from pathlib import Path

# %%
ls
# Out:
#  Volume in drive C is BOOTCAMP
#  Volume Serial Number is 0246-9FF7
#
#  Directory of C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW
#
# 03/08/2022  09:10 PM    <DIR>          .
# 03/08/2022  09:10 PM    <DIR>          ..
# 03/08/2022  08:10 PM    <DIR>          Aaron_Eckhart
# 03/08/2022  08:10 PM    <DIR>          Aaron_Guiel
# 03/08/2022  08:09 PM    <DIR>          Aaron_Patterson
# 03/08/2022  08:09 PM    <DIR>          Aaron_Peirsol
# 03/08/2022  08:10 PM    <DIR>          Aaron_Pena
# 03/08/2022  08:09 PM    <DIR>          Aaron_Sorkin
# 03/08/2022  08:09 PM    <DIR>          Aaron_Tippin
# 03/08/2022  08:09 PM    <DIR>          Abba_Eban
# 03/08/2022  08:09 PM    <DIR>          Abbas_Kiarostami
# 03/08/2022  08:10 PM    <DIR>          Abdel_Aziz_Al-Hakim
# 03/08/2022  08:10 PM    <DIR>          Abdel_Madi_Shabneh
# 03/08/2022  08:09 PM    <DIR>          Abdel_Nasser_Assidi
# 03/08/2022  08:09 PM    <DIR>          Abdoulaye_Wade
# ...

# %%
print(Path(r'LFW'))
# Out:
# LFW

# %%
count = 1010;
# os.chdir(r"C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW")
dest = "C:/Users/namtu/Documents/ML/Learn_YOLO/Image_Process/Dataset"

# iterate through all file
for files in os.listdir(r"C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW"):
    for file in os.listdir(files):
        dirname = os.path.abspath(files)
        filename = os.path.basename(file)
        fullname = dirname+"\\"+filename
#         print(fullname)
#          print(os.path.abspath(files)+os.path.basename(file))
#          print(len(os.path.abspath(files)))
#          print(os.path.basename(file))
#         img = cv2.imread(os.path.abspath(file))
#         cv2.imwrite(dest+str(file),img)
        shutil.move(fullname,dest)
        
        
        
        
        
# print('File name :    ', os.path.basename(__file__))
# print('Directory Name:     ', os.path.dirname(__file__))
        
#         source = (Path(files)
        
#         shutil.move(source,dest)
#         img = cv2.imread(file)
#         imgname = f'C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\Dataset\{count}'
#         cv2.imwrite(imgname+'.jpg',img)
#         count += 1

            
#         print(Path(file))
#         count +=1
# if count == 5:
#     break;
        
#         img = cv2.imread(Path(file))
#         img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#         shutil.move(img,r"/Dataset")
#         count +=1
# if count == 5:
#     break
#     # Check whether file is in text format or not
# #     jpg = glob(file.endswith("*.jpg"))
# Out:
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Eckhart\Aaron_Eckhart_0001.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Guiel\Aaron_Guiel_0001.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Patterson\Aaron_Patterson_0001.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Peirsol\Aaron_Peirsol_0001.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Peirsol\Aaron_Peirsol_0002.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Peirsol\Aaron_Peirsol_0003.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Peirsol\Aaron_Peirsol_0004.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Pena\Aaron_Pena_0001.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Sorkin\Aaron_Sorkin_0001.jpg
# C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW\Aaron_Sorkin\Aaron_Sorkin_0002.jpg
# ...

# %%
# count = 0;
# os.chdir(r"C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\LFW")


# # iterate through all file
# for file in os.listdir():
#     # Check whether file is in text format or not
#     jpg = glob(file.endswith("*.jpg"))
# #     if file.endswith(".jpg"):
# #         shutil.move(Path(file),r"C:\Users\namtu\Documents\ML\Learn_YOLO\Image_Process\Dataset")
#     for j in jpg:
#         print("0")
#         count +=1
#     if count == 5:
#         break
